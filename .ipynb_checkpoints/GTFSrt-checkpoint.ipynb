# %% [markdown]
# # Gathering Real-time GTFS Data

# %% [markdown]
# Importing stop data from LA Metro and Santa Monica Big Blue Bus and constraining to the Palisades and Sunset evacuation zones.

# %%
import pandas as pd
metrostops = pd.read_csv('stops.txt')
metrostops.head()
# Out:
#    stop_id  stop_code                            stop_name  stop_desc  \
# 0        1          1                  Paramount / Slauson        NaN
# 1        3          3                     Jefferson / 10th        NaN
# 2        6          6           120th / Augustus F Hawkins        NaN
# 3        7          7  120th / Martin Luther King Hospital        NaN
# 4       12         12                    15054 Sherman Way        NaN
#
#     stop_lat    stop_lon  stop_url  location_type  parent_station  tpis_name
# 0  33.973248 -118.113113       NaN            NaN             NaN        NaN
# 1  34.025471 -118.328402       NaN            NaN             NaN        NaN
# 2  33.924696 -118.242222       NaN            NaN             NaN        NaN
# 3  33.924505 -118.240369       NaN            NaN             NaN        NaN
# 4  34.201075 -118.461953       NaN            NaN             NaN        NaN

# %%
import geopandas as gpd
metrostopsGdf = gpd.GeoDataFrame(metrostops,geometry = gpd.points_from_xy(metrostops.stop_lon,metrostops.stop_lat),crs='EPSG:4326')

# %%
import matplotlib.pyplot as plt
import contextily as ctx
fig, ax = plt.subplots(figsize=(10,10))
metrostopsGdf.to_crs('EPSG:3857').plot(ax=ax)
ctx.add_basemap(ax=ax, alpha=0.5, zoom=13)

# %%
pal_perim = gpd.read_file('GTFS Data/Palisades_Perimeter_20250121.zip')
pal_perim.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pal_perim = gpd.read_file('GTFS Data/Palisades_Perimeter_20250121.zip')
#       2 pal_perim.head()
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/geopandas/io/file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/geopandas/io/file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
#     539         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     540         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)    543         stacklevel=3,
#     544     )
#     545     kwargs["columns"] = kwargs.pop("include_fields")
# --> 547 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/pyogrio/geopandas.py:265, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     260 if not use_arrow:
#     261     # For arrow, datetimes are read as is.
#     262     # For numpy IO, datetimes are read as string values to preserve timezone info
#     263     # as numpy does not directly support timezones.
#     264     kwargs["datetime_as_string"] = True
# --> 265 result = read_func(
#     266     path_or_buffer,
#     267     layer=layer,
#     268     encoding=encoding,
#     269     columns=columns,
#     270     read_geometry=read_geometry,
#     271     force_2d=gdal_force_2d,
#     272     skip_features=skip_features,
#     273     max_features=max_features,
#     274     where=where,
#     275     bbox=bbox,
#     276     mask=mask,
#     277     fids=fids,
#     278     sql=sql,
#     279     sql_dialect=sql_dialect,
#     280     return_fids=fid_as_index,
#     281     **kwargs,
#     282 )
#     284 if use_arrow:
#     285     meta, table = result
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/pyogrio/raw.py:198, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      59 """Read OGR data source into numpy arrays.
#      60
#      61 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)    194
#     195 """
#     196 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 198 return ogr_read(
#     199     get_vsi_path_or_buffer(path_or_buffer),
#     200     layer=layer,
#     201     encoding=encoding,
#     202     columns=columns,
#     203     read_geometry=read_geometry,
#     204     force_2d=force_2d,
#     205     skip_features=skip_features,
#     206     max_features=max_features or 0,
#     207     where=where,
#     208     bbox=bbox,
#     209     mask=_mask_to_wkb(mask),
#     210     fids=fids,
#     211     sql=sql,
#     212     sql_dialect=sql_dialect,
#     213     return_fids=return_fids,
#     214     dataset_kwargs=dataset_kwargs,
#     215     datetime_as_string=datetime_as_string,
#     216 )
#
# File pyogrio/_io.pyx:1240, in pyogrio._io.ogr_read()
#
# File pyogrio/_io.pyx:220, in pyogrio._io.ogr_open()
#
# DataSourceError: '/vsizip/GTFS Data/Palisades_Perimeter_20250121.zip' does not exist in the file system, and is not recognized as a supported dataset name.

# %%
fire_perim = gpd.read_file('CalFire_Perimeters_(NIFC_FIRIS)_Public_View_-_Fire_Extent_Layer.zip')
fire_perim.head()

# %%
import matplotlib.pyplot as plt
import contextily as ctx
fig, ax = plt.subplots(figsize=(10,10))
pal_perim.to_crs('EPSG:3857').plot(color='r',ax=ax)
metrostopsGdf.to_crs('EPSG:3857').plot(ax=ax)
ctx.add_basemap(ax=ax, alpha=0.5, zoom=13)

# %% [markdown]
# Maximum Intent Evacuation Zones

# %%
evac_zones = gpd.read_file('Data/Maximum Extent Evacuation Zones.shp')
evac_zones.head()
# Out:
#                 zoneId country_ab state_abbr county_abb city_abbr zone_seque  \
# 0   US-CA-XLA-LAC-E119         US         CA        XLA       LAC       E119
# 1  US-CA-XLA-SCL-RANCH         US         CA        XLA       SCL      RANCH
# 2  US-CA-XLA-LOS-Q1116         US         CA        XLA       LOS      Q1116
# 3   US-CA-XLA-CAL-C407         US         CA        XLA       CAL       C407
# 4   US-CA-XLA-SDP-U029         US         CA        XLA       SDP       U029
#
#   city_zone_ incident_n          most_extre    Shape__Are     Shape__Len  \
# 0   LAC-E119      HURST    Evacuation Order  4.126499e+08  113231.522052
# 1  SCL-RANCH      HURST  Evacuation Warning  7.208630e+07   43886.728092
# 2  LOS-Q1116  PALISADES    Evacuation Order  8.429632e+06   19035.910336
# 3   CAL-C407  PALISADES  Evacuation Warning  3.845958e+07   34610.842732
# 4   SDP-U029  PALISADES    Evacuation Order  1.080486e+08   79915.287395
#
#                                             geometry
# 0  POLYGON ((6435615.007 1958853.548, 6435583.257...
# 1  POLYGON ((6411696.4 1954312.647, 6411480.18 19...
# 2  POLYGON ((6390582.747 1849757.499, 6390486.198...
# 3  POLYGON ((6364969.561 1871318.131, 6364968.381...
# 4  POLYGON ((6354282.802 1849455.576, 6354323.715...

# %%
#evac_zones = evac_zones[evac_zones['incident_n' == 'EATON'or'incident_n'=='PALISADES' or 'incident_n'=='SUNSET']]
evac_zones = evac_zones[(evac_zones['incident_n'] == 'EATON') | (evac_zones['incident_n'] == 'PALISADES')|(evac_zones['incident_n'] == 'SUNSET')]
evac_zones.head()
# Out:
#                     zoneId country_ab state_abbr county_abb city_abbr  \
# 2      US-CA-XLA-LOS-Q1116         US         CA        XLA       LOS
# 3       US-CA-XLA-CAL-C407         US         CA        XLA       CAL
# 4       US-CA-XLA-SDP-U029         US         CA        XLA       SDP
# 6   US-CA-XLA-LCF-MEMORIAL         US         CA        XLA       LCF
# 7  US-CA-XLA-LCF-INVERNESS         US         CA        XLA       LCF
#
#   zone_seque     city_zone_ incident_n          most_extre    Shape__Are  \
# 2      Q1116      LOS-Q1116  PALISADES    Evacuation Order  8.429632e+06
# 3       C407       CAL-C407  PALISADES  Evacuation Warning  3.845958e+07
# 4       U029       SDP-U029  PALISADES    Evacuation Order  1.080486e+08
# 6   MEMORIAL   LCF-MEMORIAL      EATON    Evacuation Order  6.725536e+06
# 7  INVERNESS  LCF-INVERNESS      EATON    Evacuation Order  1.365870e+07
#
#      Shape__Len                                           geometry
# 2  19035.910336  POLYGON ((6390582.747 1849757.499, 6390486.198...
# 3  34610.842732  POLYGON ((6364969.561 1871318.131, 6364968.381...
# 4  79915.287395  POLYGON ((6354282.802 1849455.576, 6354323.715...
# 6  10256.712422  POLYGON ((6499364.348 1897819.608, 6499299.425...
# 7  18009.132944  POLYGON ((6504541.613 1887166.887, 6504454.983...

# %%
evac_zones.crs
# Out:
# <Projected CRS: EPSG:2229>
# Name: NAD83 / California zone 5 (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - California - counties Kern; Los Angeles; San Bernardino; San Luis Obispo; Santa Barbara; Ventura.
# - bounds: (-121.42, 32.76, -114.12, 35.81)
# Coordinate Operation:
# - name: SPCS83 California zone 5 (US survey foot)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
import matplotlib.pyplot as plt
import contextily as ctx
fig, ax = plt.subplots(figsize=(10,10))
evac_zones.to_crs('EPSG:3857').plot(color='r',ax=ax)
metrostopsGdf.to_crs('EPSG:3857').plot(ax=ax)
ctx.add_basemap(ax=ax, alpha=0.5, zoom=13)

# %%
firejoin = gpd.sjoin(metrostopsGdf.to_crs('EPSG:2229'),evac_zones.to_crs('EPSG:2229'))
firejoin.head()
# Out:
#      stop_id  stop_code                     stop_name  stop_desc   stop_lat  \
# 25        65         65           Agoura / Lost Hills        NaN  34.139410
# 35        86         86            Allen / Washington        NaN  34.169413
# 329      546        546           Cahuenga / Franklin        NaN  34.105321
# 330      548        548  Cahuenga / Universal Studios        NaN  34.132332
# 331      549        549             Cahuenga / Wright        NaN  34.119376
#
#        stop_lon  stop_url  location_type  parent_station  tpis_name  ...  \
# 25  -118.708608       NaN            NaN             NaN        NaN  ...
# 35  -118.112873       NaN            NaN             NaN        NaN  ...
# 329 -118.330615       NaN            NaN             NaN        NaN  ...
# 330 -118.353024       NaN            NaN             NaN        NaN  ...
# 331 -118.339502       NaN            NaN             NaN        NaN  ...
#
#     country_ab  state_abbr county_abb city_abbr zone_seque city_zone_  \
# 25          US          CA        XLA       CAL       C405   CAL-C405
# 35          US          CA        XLA       LAC       E179   LAC-E179
# 329         US          CA        XLA       LOS      Q0841  LOS-Q0841
# 330         US          CA        XLA       LOS      Q0521  LOS-Q0521
# 331         US          CA        XLA       LOS      Q0842  LOS-Q0842
#
#     incident_n          most_extre    Shape__Are    Shape__Len
# 25   PALISADES  Evacuation Warning  6.982940e+07  45358.932757
# 35       EATON    Evacuation Order  1.041092e+07  14499.986561
# 329     SUNSET    Evacuation Order  1.140769e+07  17947.998267
# 330     SUNSET  Evacuation Warning  1.634804e+07  22221.237524
# 331     SUNSET    Evacuation Order  4.099892e+06  11836.673343
#
# [5 rows x 23 columns]

# %%
firejoin.describe()
# Out:
#             stop_id     stop_code  stop_desc    stop_lat    stop_lon  \
# count  4.890000e+02  4.890000e+02        0.0  489.000000  489.000000
# mean   6.427566e+05  6.427566e+05        NaN   34.121759 -118.340271
# std    6.383032e+06  6.383032e+06        NaN    0.056687    0.189611
# min    6.500000e+01  6.500000e+01        NaN   34.020667 -118.724725
# 25%    3.756000e+03  3.756000e+03        NaN   34.061592 -118.495549
# 50%    9.268000e+03  9.268000e+03        NaN   34.128667 -118.338710
# 75%    1.281300e+04  1.281300e+04        NaN   34.168627 -118.150631
# max    7.050000e+07  7.050000e+07        NaN   34.240423 -118.052819
#
#        stop_url  location_type  parent_station  tpis_name  index_right  \
# count       0.0            0.0             0.0        0.0   489.000000
# mean        NaN            NaN             NaN        NaN   191.010225
# std         NaN            NaN             NaN        NaN    76.584103
# min         NaN            NaN             NaN        NaN    14.000000
# 25%         NaN            NaN             NaN        NaN   127.000000
# 50%         NaN            NaN             NaN        NaN   202.000000
# 75%         NaN            NaN             NaN        NaN   245.000000
# max         NaN            NaN             NaN        NaN   314.000000
#
#          Shape__Are     Shape__Len
# count  4.890000e+02     489.000000
# mean   2.340616e+07   24279.574696
# std    2.975570e+07   13205.111976
# min    2.020273e+06    6437.156375
# 25%    1.159255e+07   17800.563643
# 50%    1.596156e+07   20505.394864
# 75%    2.320619e+07   23970.859609
# max    3.835183e+08  118047.412906

# %%
import matplotlib.pyplot as plt
import contextily as ctx
fig, ax = plt.subplots(figsize=(10,10))
evac_zones.to_crs('EPSG:3857').plot(color='r',ax=ax)
firejoin.to_crs('EPSG:3857').plot(ax=ax)
ctx.add_basemap(ax=ax, alpha=0.5, zoom=13)
